# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
x=df.isnull().sum()

# %%
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# peakrpm          -0.203789   0.273606  -0.360469  -0.287242 -0.220012
# citympg           0.015940  -0.035823  -0.470414  -0.670909 -0.642704
# highwaympg        0.011255   0.034606  -0.544082  -0.704662 -0.677218
# price            -0.109093  -0.079978   0.577816   0.682920  0.759325
#
#                   carheight  curbweight  enginesize  boreratio    stroke  \
# car_ID             0.255960    0.071962   -0.033930   0.260064 -0.160824
# symboling         -0.541038   -0.227691   -0.105790  -0.130051 -0.008735
# wheelbase          0.589435    0.776386    0.569329   0.488750  0.160959
# carlength          0.491029    0.877728    0.683360   0.606454  0.129533
# carwidth           0.279210    0.867032    0.735433   0.559150  0.182942
# carheight          1.000000    0.295572    0.067149   0.171071 -0.055307
# curbweight         0.295572    1.000000    0.850594   0.648480  0.168790
# enginesize         0.067149    0.850594    1.000000   0.583774  0.203129
# boreratio          0.171071    0.648480    0.583774   1.000000 -0.055909
# stroke            -0.055307    0.168790    0.203129  -0.055909  1.000000
# compressionratio   0.261214    0.151362    0.028971   0.005197  0.186110
# horsepower        -0.108802    0.750739    0.809769   0.573677  0.080940
# peakrpm           -0.320411   -0.266243   -0.244660  -0.254976 -0.067964
# citympg           -0.048640   -0.757414   -0.653658  -0.584532 -0.042145
# highwaympg        -0.107358   -0.797465   -0.677470  -0.587012 -0.043931
# price              0.119336    0.835305    0.874145   0.553173  0.079443
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# car_ID                    0.150276   -0.015006 -0.203789  0.015940
# symboling                -0.178515    0.070873  0.273606 -0.035823
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.067984    0.808139 -0.085267 -0.685751
#
#                   highwaympg     price
# car_ID              0.011255 -0.109093
# symboling           0.034606 -0.079978
# wheelbase          -0.544082  0.577816
# carlength          -0.704662  0.682920
# carwidth           -0.677218  0.759325
# carheight          -0.107358  0.119336
# curbweight         -0.797465  0.835305
# enginesize         -0.677470  0.874145
# boreratio          -0.587012  0.553173
# stroke             -0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower         -0.770544  0.808139
# peakrpm            -0.054275 -0.085267
# citympg             0.971337 -0.685751
# highwaympg          1.000000 -0.697599
# price              -0.697599  1.000000

# %%
sns.heatmap(df.isnull(),yticklabels=False)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
x=df['drivewheel'].value_counts()
x
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
df['CarName'].value_counts()
# Out:
# toyota corona               6
# peugeot 504                 6
# toyota corolla              6
# subaru dl                   4
# mitsubishi g4               3
#                            ..
# buick century luxus (sw)    1
# subaru brz                  1
# plymouth cricket            1
# chevrolet vega 2300         1
# buick electra 225 custom    1
# Name: CarName, Length: 147, dtype: int64

# %%
df.sum()
# Out:
# car_ID                                                          21115
# symboling                                                         171
# CarName             alfa-romero giuliaalfa-romero stelvioalfa-rome...
# fueltype            gasgasgasgasgasgasgasgasgasgasgasgasgasgasgasg...
# aspiration          stdstdstdstdstdstdstdstdturboturbostdstdstdstd...
# doornumber          twotwotwofourfourtwofourfourfourtwotwofourtwof...
# carbody             convertibleconvertiblehatchbacksedansedansedan...
# drivewheel          rwdrwdrwdfwd4wdfwdfwdfwdfwd4wdrwdrwdrwdrwdrwdr...
# enginelocation      frontfrontfrontfrontfrontfrontfrontfrontfrontf...
# wheelbase                                                     20245.1
# carlength                                                     35680.1
# carwidth                                                      13511.1
# carheight                                                     11013.6
# curbweight                                                     523891
# enginetype          dohcdohcohcvohcohcohcohcohcohcohcohcohcohcohco...
# cylindernumber      fourfoursixfourfivefivefivefivefivefivefourfou...
# enginesize                                                      26016
# fuelsystem          mpfimpfimpfimpfimpfimpfimpfimpfimpfimpfimpfimp...
# boreratio                                                       682.6
# stroke                                                         667.36
# compressionratio                                              2079.22
# horsepower                                                      21344
# peakrpm                                                       1050650
# citympg                                                          5170
# highwaympg                                                       6304
# price                                                     2.72173e+06
# dtype: object

# %%
df['enginetype'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# l         12
# dohc      12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
df1=df.drop(['car_ID','symboling','CarName','doornumber','carbody'],axis=1)
df1
# Out:
#     fueltype aspiration drivewheel enginelocation  wheelbase  carlength  \
# 0        gas        std        rwd          front       88.6      168.8
# 1        gas        std        rwd          front       88.6      168.8
# 2        gas        std        rwd          front       94.5      171.2
# 3        gas        std        fwd          front       99.8      176.6
# 4        gas        std        4wd          front       99.4      176.6
# ..       ...        ...        ...            ...        ...        ...
# 200      gas        std        rwd          front      109.1      188.8
# 201      gas      turbo        rwd          front      109.1      188.8
# 202      gas        std        rwd          front      109.1      188.8
# 203   diesel      turbo        rwd          front      109.1      188.8
# 204      gas      turbo        rwd          front      109.1      188.8
#
#      carwidth  carheight  curbweight enginetype  ... enginesize  fuelsystem  \
# 0        64.1       48.8        2548       dohc  ...        130        mpfi
# 1        64.1       48.8        2548       dohc  ...        130        mpfi
# 2        65.5       52.4        2823       ohcv  ...        152        mpfi
# 3        66.2       54.3        2337        ohc  ...        109        mpfi
# 4        66.4       54.3        2824        ohc  ...        136        mpfi
# ..        ...        ...         ...        ...  ...        ...         ...
# 200      68.9       55.5        2952        ohc  ...        141        mpfi
# 201      68.8       55.5        3049        ohc  ...        141        mpfi
# 202      68.9       55.5        3012       ohcv  ...        173        mpfi
# 203      68.9       55.5        3217        ohc  ...        145         idi
# 204      68.9       55.5        3062        ohc  ...        141        mpfi
#
#     boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0        3.47    2.68               9.0         111     5000       21
# 1        3.47    2.68               9.0         111     5000       21
# 2        2.68    3.47               9.0         154     5000       19
# 3        3.19    3.40              10.0         102     5500       24
# 4        3.19    3.40               8.0         115     5500       18
# ..        ...     ...               ...         ...      ...      ...
# 200      3.78    3.15               9.5         114     5400       23
# 201      3.78    3.15               8.7         160     5300       19
# 202      3.58    2.87               8.8         134     5500       18
# 203      3.01    3.40              23.0         106     4800       26
# 204      3.78    3.15               9.5         114     5400       19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 21 columns]

# %%
x=df1.iloc[:,:-1]
x.head()
# Out:
#   fueltype aspiration drivewheel enginelocation  wheelbase  carlength  \
# 0      gas        std        rwd          front       88.6      168.8
# 1      gas        std        rwd          front       88.6      168.8
# 2      gas        std        rwd          front       94.5      171.2
# 3      gas        std        fwd          front       99.8      176.6
# 4      gas        std        4wd          front       99.4      176.6
#
#    carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# 0      64.1       48.8        2548       dohc           four         130
# 1      64.1       48.8        2548       dohc           four         130
# 2      65.5       52.4        2823       ohcv            six         152
# 3      66.2       54.3        2337        ohc           four         109
# 4      66.4       54.3        2824        ohc           five         136
#
#   fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       mpfi       3.47    2.68               9.0         111     5000
# 1       mpfi       3.47    2.68               9.0         111     5000
# 2       mpfi       2.68    3.47               9.0         154     5000
# 3       mpfi       3.19    3.40              10.0         102     5500
# 4       mpfi       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg
# 0       21          27
# 1       21          27
# 2       19          26
# 3       24          30
# 4       18          22

# %%
X=pd.get_dummies(x,drop_first=True)
X.head()
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=None)

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([ 5604.93668313,  6965.68310182, 35482.91041368, 13126.99088045,
#         6030.23413775, 16717.68681131, 14084.26069435,  5460.25431698,
#         7297.32414736,  5425.93129689, 17342.45364898, 10059.31088975,
#        14803.34705217, 22697.6321165 , 17775.69044686, 10377.45500664,
#         8135.2518258 ,  6305.47053892, 10217.90418789, 11572.64158874,
#         9637.95531769,  7073.809028  ,  8948.39839184, 27321.97832745,
#         6978.32742458,  6678.04328389, 11433.81119402, 40591.83955094,
#        10884.44802727,  9661.32702963, 11441.35394177, 10661.13929189,
#        15995.12649298, 15943.09659855, 10963.2552084 ,  7340.36861265,
#        12055.50516896, 10255.24382276,  5984.35001636,  6697.77437144,
#         9125.69666603, 22196.62874133, 27827.736278  , 13074.92129897,
#         6461.18998299, 17197.23559423, 27429.06419132,  7529.67537755,
#        10955.60957701,  6178.96257642,  7395.1314011 ,  8521.14775897,
#        10716.36928145, 18262.0395474 ,  7308.4888899 ,  8096.28621896,
#        48422.70108834, 20283.74905888,  7798.14328421, 15972.65885609,
#         7742.6023973 , 11572.64158874])

# %%
y_train
# Out:
# 94      7299.0
# 54      7395.0
# 22      6377.0
# 95      7799.0
# 178    16558.0
#         ...
# 8      23875.0
# 12     20970.0
# 182     7775.0
# 47     32250.0
# 131     9895.0
# Name: price, Length: 143, dtype: float64

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.8085624773068887
